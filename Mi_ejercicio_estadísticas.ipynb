# %% [markdown]
# <a href="https://colab.research.google.com/github/JECABRIFA/Diplomado_IA/blob/main/Mi_ejercicio_estad%C3%ADsticas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd  # Para el manejo de los datos
import numpy as np # Para el manejo de operaciones entre datos, y las columnas
import matplotlib.pyplot as plt # Para el manejo de las graficas
import seaborn as sns # Para el manejo de graficas

# %%
df = pd.read_excel('/content/ESTADISTICAS PERMISOS-INCAPACIDADESdic024 ia.xlsx')

# %%
df.head(20)
# Out:
#    Unnamed: 0 Unnamed: 1  Unnamed: 2             Unnamed: 3 Unnamed: 4  \
# 0         NaN        NaN         NaN  HORAS DE PERMISO 2024        NaN
# 1         NaN        NaN         NaN                    NaN        NaN
# 2         NaN        NaN         NaN                    NaN        NaN
# 3         NaN      Item.  TRABAJADOR                    DIA        MES
# 4         NaN          1       Ana 1                     26          2
# 5         NaN          2       Ana 2                      6          3
# 6         NaN          3       Ana 3                      9          4
# 7         NaN          4       Ana 4                     20          4
# 8         NaN          5       Ana 5                     26          4
# 9         NaN          7       Ana 6                      2          3
# 10        NaN          8       Ana 7                      7          5
# 11        NaN          9       Ana 8                      5          5
# ...
